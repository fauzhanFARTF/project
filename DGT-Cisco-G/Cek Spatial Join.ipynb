# %%
import geopandas as gpd
DesaAll = gpd.read_file(r'assets/Desa.shp')

# %%
DesaAll
# Out:
#      LATITUDE   LONGITUDE PEMERINTAH         DESA_KEL   KECAMATAN  LUAS_KM2  \
# 0   -6.214514  106.600251  KELURAHAN        BENCONGAN  KELAPA DUA      3.09
# 1   -6.234806  106.614957  KELURAHAN       KELAPA DUA  KELAPA DUA      4.66
# 2   -6.267557  106.614161  KELURAHAN           MEDANG  PAGEDANGAN      4.71
# 3   -6.233059  106.599560  KELURAHAN  BENCONGAN INDAH  KELAPA DUA      3.61
# 4   -6.238642  106.632004  KELURAHAN  PAKULONAN BARAT  KELAPA DUA      4.43
# ..        ...         ...        ...              ...         ...       ...
# 269 -6.034223  106.560553       DESA    KARANG SERANG    SUKADIRI      3.20
# 270 -6.089786  106.541972       DESA    JATI WARINGIN        MAUK      2.05
# 271 -6.165556  106.440966       DESA            MERAK   SUKAMULYA      2.72
# 272 -6.119165  106.575713  KELURAHAN          SEPATAN     SEPATAN      2.60
# 273 -6.108230  106.584095       DESA          SARAKAN     SEPATAN      1.94
#
# ...

# %%
type(DesaAll)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
DesaAll.plot(figsize=(15,30))
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt

fix, ax = plt.subplots(figsize = (15,30))
DesaAll.plot(ax=ax)

DesaAll.plot(ax=ax, alpha=0.7, color ="pink", linewidth=0.8, edgecolor='0.8')
# Out:
# <AxesSubplot:>

# %%
desa_select_gdf = DesaAll[['DESA_KEL','KECAMATAN','LUAS_KM2','KEP_PEND','geometry']]
desa_select_gdf
# Out:
#             DESA_KEL   KECAMATAN  LUAS_KM2      KEP_PEND  \
# 0          BENCONGAN  KELAPA DUA      3.09  16925.889968
# 1         KELAPA DUA  KELAPA DUA      4.66   9301.502146
# 2             MEDANG  PAGEDANGAN      4.71   6615.286624
# 3    BENCONGAN INDAH  KELAPA DUA      3.61   4765.650970
# 4    PAKULONAN BARAT  KELAPA DUA      4.43   6933.634312
# ..               ...         ...       ...           ...
# 269    KARANG SERANG    SUKADIRI      3.20   2223.750000
# 270    JATI WARINGIN        MAUK      2.05   5743.902439
# 271            MERAK   SUKAMULYA      2.72   2690.808824
# 272          SEPATAN     SEPATAN      2.60   4521.538462
# 273          SARAKAN     SEPATAN      1.94   5856.185567
#
#                                               geometry
# 0    POLYGON ((106.60974 -6.22009, 106.60963 -6.220...
# 1    POLYGON ((106.62796 -6.22866, 106.62684 -6.231...
# 2    POLYGON ((106.62931 -6.26297, 106.63025 -6.269...
# 3    POLYGON ((106.60290 -6.21905, 106.60286 -6.219...
# ...

# %%
desa_select_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
desa_select_gdf.shape
# Out:
# (274, 5)

# %%
desa_select_gdf.columns
# Out:
# Index(['DESA_KEL', 'KECAMATAN', 'LUAS_KM2', 'KEP_PEND', 'geometry'], dtype='object')

# %%
Kolombaru = {'DESA_KEL':'Nama Desa','KECAMATAN' : 'Nama Kecamatan', 'LUAS_KM2':'Luas Km2' , 'KEP_PEND' : 'Kepadatan Penduduk' }

# %%
desa_select_gdf.rename(columns=Kolombaru, inplace=True)
desa_select_gdf
# Out:
# /var/folders/vd/jt9z824x605fdy42p_d8k3fm0000gn/T/ipykernel_5549/3014133463.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   desa_select_gdf.rename(columns=Kolombaru, inplace=True)
#            Nama Desa Nama Kecamatan  Luas Km2  Kepadatan Penduduk  \
# 0          BENCONGAN     KELAPA DUA      3.09        16925.889968
# 1         KELAPA DUA     KELAPA DUA      4.66         9301.502146
# 2             MEDANG     PAGEDANGAN      4.71         6615.286624
# 3    BENCONGAN INDAH     KELAPA DUA      3.61         4765.650970
# 4    PAKULONAN BARAT     KELAPA DUA      4.43         6933.634312
# ..               ...            ...       ...                 ...
# 269    KARANG SERANG       SUKADIRI      3.20         2223.750000
# 270    JATI WARINGIN           MAUK      2.05         5743.902439
# ...

# %%
desa_select_gdf['Luas Mil'] = desa_select_gdf['Luas Km2'] * 0.621371
desa_select_gdf
# Out:
# /Users/fauzan_nurrachman/opt/anaconda3/envs/fauzanenv/lib/python3.9/site-packages/geopandas/geodataframe.py:1351: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)
#            Nama Desa Nama Kecamatan  Luas Km2  Kepadatan Penduduk  \
# 0          BENCONGAN     KELAPA DUA      3.09        16925.889968
# 1         KELAPA DUA     KELAPA DUA      4.66         9301.502146
# 2             MEDANG     PAGEDANGAN      4.71         6615.286624
# 3    BENCONGAN INDAH     KELAPA DUA      3.61         4765.650970
# 4    PAKULONAN BARAT     KELAPA DUA      4.43         6933.634312
# ..               ...            ...       ...                 ...
# 269    KARANG SERANG       SUKADIRI      3.20         2223.750000
# ...

# %%
desa_index_gdf=  desa_select_gdf.set_index("Nama Kecamatan")
desa_index_gdf
# Out:
#                       Nama Desa  Luas Km2  Kepadatan Penduduk  \
# Nama Kecamatan
# KELAPA DUA            BENCONGAN      3.09        16925.889968
# KELAPA DUA           KELAPA DUA      4.66         9301.502146
# PAGEDANGAN               MEDANG      4.71         6615.286624
# KELAPA DUA      BENCONGAN INDAH      3.61         4765.650970
# KELAPA DUA      PAKULONAN BARAT      4.43         6933.634312
# ...                         ...       ...                 ...
# SUKADIRI          KARANG SERANG      3.20         2223.750000
# MAUK              JATI WARINGIN      2.05         5743.902439
# SUKAMULYA                 MERAK      2.72         2690.808824
# SEPATAN                 SEPATAN      2.60         4521.538462
# SEPATAN                 SARAKAN      1.94         5856.185567
#
#                                                          geometry  Luas Mil
# Nama Kecamatan
# KELAPA DUA      POLYGON ((106.60974 -6.22009, 106.60963 -6.220...  1.920036
# ...

# %%
desa_index_gdf.groupby(['Nama Kecamatan']).agg(["count"])['geometry']
# Out:
#                 count
# Nama Kecamatan
# BALARAJA            9
# CIKUPA             14
# CISAUK              6
# CISOKA             10
# CURUG               7
# GUNUNG KALER        9
# JAMBE              10
# JAYANTI             8
# KELAPA DUA          6
# KEMIRI              7
# KOSAMBI            10
# KRESEK              9
# KRONJO             10
# LEGOK              11
# MAUK               12
# MEKAR BARU          8
# PAGEDANGAN         11
# PAKUHAJI           14
# PANONGAN            8
# PASAR KEMIS         9
# RAJEG              13
# SEPATAN             8
# SEPATAN TIMUR       8
# SINDANG JAYA        7
# SOLEAR              7
# SUKADIRI            8
# SUKAMULYA           8
# TELUKNAGA          13
# TIGARAKSA          14

# %%
data_kecamatan_cikupa = desa_select_gdf.loc[desa_select_gdf['Nama Kecamatan'] == 'CIKUPA']
data_kecamatan_cikupa
# Out:
#         Nama Desa Nama Kecamatan  Luas Km2  Kepadatan Penduduk  \
# 21      SUKADAMAI         CIKUPA      4.51         5041.019956
# 22          DUKUH         CIKUPA      3.31         5168.580060
# 39        CIBADAK         CIKUPA      2.80         4372.857143
# 40      SUKAMULYA         CIKUPA      2.92         9855.136986
# 72         CIKUPA         CIKUPA      2.05        11882.439024
# 75         TALAGA         CIKUPA      4.12         4904.368932
# 76    TALAGA SARI         CIKUPA      2.71         8951.291513
# 77         BUNDER         CIKUPA      5.20         3196.923077
# 78    BITUNG JAYA         CIKUPA      1.87         8132.620321
# 79   PASIR GADUNG         CIKUPA      2.62         8910.687023
# 80     PASIR JAYA         CIKUPA      2.42        12939.669421
# 102    BUDI MULYA         CIKUPA      3.30         1489.696970
# 103        BOJONG         CIKUPA      3.45         5167.246377
# 104    SUKANAGARA         CIKUPA      2.15         5445.581395
#
# ...

# %%
data_kecamatan_cikupa.plot(figsize=(15,30))
# Out:
# <AxesSubplot:>

# %%
data_kecamatan_cikupa.loc[data_kecamatan_cikupa['Luas Mil'].idxmax()]
# Out:
# Nama Desa                                                        BUNDER
# Nama Kecamatan                                                   CIKUPA
# Luas Km2                                                            5.2
# Kepadatan Penduduk                                          3196.923077
# geometry              POLYGON ((106.548830119142 -6.182924517596264,...
# Luas Mil                                                       3.231129
# Name: 77, dtype: object

# %%
data_kecamatan_cikupa_index_gdf=  desa_select_gdf.set_index("Nama Desa")
data_kecamatan_cikupa_index_gdf
# Out:
#                 Nama Kecamatan  Luas Km2  Kepadatan Penduduk  \
# Nama Desa
# BENCONGAN           KELAPA DUA      3.09        16925.889968
# KELAPA DUA          KELAPA DUA      4.66         9301.502146
# MEDANG              PAGEDANGAN      4.71         6615.286624
# BENCONGAN INDAH     KELAPA DUA      3.61         4765.650970
# PAKULONAN BARAT     KELAPA DUA      4.43         6933.634312
# ...                        ...       ...                 ...
# KARANG SERANG         SUKADIRI      3.20         2223.750000
# JATI WARINGIN             MAUK      2.05         5743.902439
# MERAK                SUKAMULYA      2.72         2690.808824
# SEPATAN                SEPATAN      2.60         4521.538462
# SARAKAN                SEPATAN      1.94         5856.185567
#
#                                                           geometry  Luas Mil
# Nama Desa
# BENCONGAN        POLYGON ((106.60974 -6.22009, 106.60963 -6.220...  1.920036
# ...

# %%
data_kecamatan_cikupa_index_gdf.at['BUNDER','geometry']

# %%
desa_index_gdf = desa_index_gdf.reset_index()
desa_index_gdf
# Out:
#     Nama Kecamatan        Nama Desa  Luas Km2  Kepadatan Penduduk  \
# 0       KELAPA DUA        BENCONGAN      3.09        16925.889968
# 1       KELAPA DUA       KELAPA DUA      4.66         9301.502146
# 2       PAGEDANGAN           MEDANG      4.71         6615.286624
# 3       KELAPA DUA  BENCONGAN INDAH      3.61         4765.650970
# 4       KELAPA DUA  PAKULONAN BARAT      4.43         6933.634312
# ..             ...              ...       ...                 ...
# 269       SUKADIRI    KARANG SERANG      3.20         2223.750000
# 270           MAUK    JATI WARINGIN      2.05         5743.902439
# 271      SUKAMULYA            MERAK      2.72         2690.808824
# 272        SEPATAN          SEPATAN      2.60         4521.538462
# 273        SEPATAN          SARAKAN      1.94         5856.185567
#
#                                               geometry  Luas Mil
# 0    POLYGON ((106.60974 -6.22009, 106.60963 -6.220...  1.920036
# ...

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[-6.1950, 106.5528], zoom_start=11)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[-6.1950, 106.5528],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[-6.1950, 106.5528],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[-6.1950, 106.5528],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
bangunan_toko_modern = gpd.read_file(r'assets/Toko_Modern_Centroids.json')

# %%
bangunan_toko_modern
# Out:
#                        N_Alfamart           Desa  Kecamatan  \
# 0           ALFAMART KP. PANGGANG     SELAPAJANG     CISOKA
# 1      INDOMARET DANAU CITRA RAYA           None       None
# 2      ALFAMART RAYA SERANG KM 17         BOJONG     CIKUPA
# 3       ALFAMART RUKO DANAU CITRA           None       None
# 4          ALFAMART PEUSAR CIKUPA      SUKAMULYA     CIKUPA
# ..                            ...            ...        ...
# 556  INDOMARET RAYA SERANG KM. 34  SUMUR BANDUNG    JAYANTI
# 557   INDOMARET ARIA JAYA SANTIKA      TIGARAKSA  TIGARAKSA
# 558             INDOMARET CISEREH      KADU JAYA      CURUG
# 559   INDOMARET CUKANGGALIH KM. 2    CURUG KULON      CURUG
# 560      INDOMARET RAJAWALI RAJEG          RAJEG      RAJEG
#
#                    NAMA_PERUS jenis                    geometry
# 0                        None  None  POINT (106.42915 -6.24355)
# 1                        None  None  POINT (106.52180 -6.23300)
# ...

# %%
bangunan_toko_modern_selected = bangunan_toko_modern[['N_Alfamart','Desa','Kecamatan', 'NAMA_PERUS',  'geometry']]
bangunan_toko_modern_selected
# Out:
#                        N_Alfamart           Desa  Kecamatan  \
# 0           ALFAMART KP. PANGGANG     SELAPAJANG     CISOKA
# 1      INDOMARET DANAU CITRA RAYA           None       None
# 2      ALFAMART RAYA SERANG KM 17         BOJONG     CIKUPA
# 3       ALFAMART RUKO DANAU CITRA           None       None
# 4          ALFAMART PEUSAR CIKUPA      SUKAMULYA     CIKUPA
# ..                            ...            ...        ...
# 556  INDOMARET RAYA SERANG KM. 34  SUMUR BANDUNG    JAYANTI
# 557   INDOMARET ARIA JAYA SANTIKA      TIGARAKSA  TIGARAKSA
# 558             INDOMARET CISEREH      KADU JAYA      CURUG
# 559   INDOMARET CUKANGGALIH KM. 2    CURUG KULON      CURUG
# 560      INDOMARET RAJAWALI RAJEG          RAJEG      RAJEG
#
#                    NAMA_PERUS                    geometry
# 0                        None  POINT (106.42915 -6.24355)
# 1                        None  POINT (106.52180 -6.23300)
# 2                        None  POINT (106.50527 -6.22473)
# ...

# %%
Kolombaru_minimarket = {'N_Alfamart':'Nama Minimarket', 'NAMA_PERUS':'Nama Perusahaan','Desa' : 'Nama Desa', 'Kecamatan':'Nama Kecamatan' } 
bangunan_toko_modern_selected.rename(columns=Kolombaru_minimarket, inplace=True)
bangunan_toko_modern_selected
# Out:
# /var/folders/vd/jt9z824x605fdy42p_d8k3fm0000gn/T/ipykernel_5549/1575762958.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bangunan_toko_modern_selected.rename(columns=Kolombaru_minimarket, inplace=True)
#                   Nama Minimarket      Nama Desa Nama Kecamatan  \
# 0           ALFAMART KP. PANGGANG     SELAPAJANG         CISOKA
# 1      INDOMARET DANAU CITRA RAYA           None           None
# 2      ALFAMART RAYA SERANG KM 17         BOJONG         CIKUPA
# 3       ALFAMART RUKO DANAU CITRA           None           None
# 4          ALFAMART PEUSAR CIKUPA      SUKAMULYA         CIKUPA
# ..                            ...            ...            ...
# 556  INDOMARET RAYA SERANG KM. 34  SUMUR BANDUNG        JAYANTI
# 557   INDOMARET ARIA JAYA SANTIKA      TIGARAKSA      TIGARAKSA
# ...

# %%
import folium
m = folium.Map(location=[-6.1950, 106.5528], zoom_start=11, tiles='CartoDB positron')

for _, r in bangunan_toko_modern_selected.iterrows():
    # Without simplifying the representation of each borough,
    # the map might not be displayed
    sim_geo = gpd.GeoSeries(r['geometry']).simplify(tolerance=0.001)
    geo_j = sim_geo.to_json()
    geo_j = folium.GeoJson(data=geo_j,
                           style_function=lambda x: {'fillColor': 'orange', 'fillOpacity' : 0, 'weight': 1})
    folium.Popup(r['Nama Minimarket']).add_to(geo_j)
    geo_j.add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
desa_index_gdf.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
bangunan_toko_modern_selected.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
gabung = gpd.sjoin(desa_index_gdf,bangunan_toko_modern_selected, how='inner',op='intersects')
gabung
# Out:
# /Users/fauzan_nurrachman/opt/anaconda3/envs/fauzanenv/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3337: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
#     Nama Kecamatan_left Nama Desa_left  Luas Km2  Kepadatan Penduduk  \
# 0            KELAPA DUA      BENCONGAN      3.09        16925.889968
# 0            KELAPA DUA      BENCONGAN      3.09        16925.889968
# 1            KELAPA DUA     KELAPA DUA      4.66         9301.502146
# 1            KELAPA DUA     KELAPA DUA      4.66         9301.502146
# 1            KELAPA DUA     KELAPA DUA      4.66         9301.502146
# ..                  ...            ...       ...                 ...
# 271           SUKAMULYA          MERAK      2.72         2690.808824
# 272             SEPATAN        SEPATAN      2.60         4521.538462
# ...
